# %% [markdown]
# https://www.kaggle.com/code/hackermanx/time-series-analysis-moving-average-methods

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path = "Sample Dataset.xlsx"
df = pd.read_excel(data_path)
df
# Out:
#            Date     Signal        Open        High         Low       Close  \
# 0    2015-11-19  13.768540  116.440002  116.650002  115.739998  116.059998
# 1    2015-11-20  13.608819  116.480003  117.360001  116.379997  116.809998
# 2    2015-11-23  12.990589  116.709999  117.889999  116.680000  117.389999
# 3    2015-11-24  12.667435  116.879997  118.419998  116.559998  118.250000
# 4    2015-11-25  13.019910  118.300003  119.320000  118.110001  119.169998
# ...         ...        ...         ...         ...         ...         ...
# 1033 2019-12-30   0.000000  165.979996  166.210007  164.570007  165.440002
# 1034 2019-12-31   0.000000  165.080002  166.350006  164.710007  165.669998
# 1035 2020-01-02   0.000000  166.740005  166.750000  164.229996  165.779999
# 1036 2020-01-03   0.000000  163.740005  165.410004  163.699997  165.130005
# 1037 2020-01-06   0.000000  163.850006  165.539993  163.539993  165.350006
#
#        Adj Close
# 0     108.281601
# 1     108.981323
# ...

# %% [markdown]
# # Task 1
# Review the quality of the data, list any potential errors, and propose corrected values. Please list each quality check error and correction applied.
# ## Preliminary Inspection of the data

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close
# count  1038.000000  1038.000000  1038.000000  1038.000000  1038.000000
# mean    141.847360   142.691801   140.907746   141.840973   136.341060
# std      18.475574    18.470255    18.404504    18.497010    21.427837
# min      94.080002    95.400002    93.639999    94.790001  -152.277847
# 25%     132.132496   132.912495   130.542503   131.824993   125.290491
# 50%     146.769997   147.959999   145.634995   146.885002   142.667732
# 75%     155.367496   156.287495   154.422500   155.289993   151.798325
# max     172.789993   173.389999   171.949997   196.279999   168.842270

# %% [markdown]
# ## Few issues observed:
#
# 1. Average `Adj Close` column is significantly smaller than that of `Close`
# 2. `Adj Close` has a negtaive `min` value
# 3. `Close` has a `max` higher than the `max` of `High`
#
# We will further take a look..

# %% [markdown]
# ## Abnormal strikes
# - From the plot below, we observe some numbers of strikes

# %%
df.drop(['Signal', 'Date'], axis=1).plot(figsize=(16,8))
# Out:
# <Axes: >

# %% [markdown]
# ## Issue 1:Data quality `Adj Close` Discrepancy
# - Average `Adj Close` column is significantly smaller than that of `Close`
# - `Adj Close` has a negtaive `min` value

# %%
df[df['Adj Close'] <= 0]
# Out:
#            Open        High         Low       Close   Adj Close
# 732  160.820007  160.990005  156.360001  156.559998 -152.277847

# %% [markdown]
# ### Corection for Issue 1
# 1. Dropping `adj close` negative value

# %% [markdown]
# ## 2. Dropping data with `Adj Close`, `Close`, `Open`, `Low` higher than `High`

# %%
df[df['Adj Close'] > df['High']]
# Out:
#            Open        High         Low       Close   Adj Close
# 262  131.970001  133.330002  131.889999  133.149994  166.175079
# 338  132.759995  135.070007  132.399994  134.740005  158.577637

# %%
df[['Close', 'Adj Close']].plot(figsize=(16,8))
# Out:
# <Axes: >

# %% [markdown]
# # Correlation Analysis
# - Plotting Signal againast Lag features (Close price with 1 day lag)
